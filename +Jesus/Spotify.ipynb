# %%
import pandas as pd

countries=["ARG", "AUS", "CAN", "ESP", "EUR", "FRA", "GBP", "GER", "ITA", "JPN", "KOR", "MEX", "SUI"]
files_name=[]
country_data={}

for x in countries:
    file=f'../Datasets/Billboard International Charts (2019-Aug 2020)/{x}.csv'
    if x=="ARG":        
        ARG=pd.read_csv(file,index_col=0)
    elif x=="AUS":
        AUS=pd.read_csv(file,index_col=0)
    elif x=="CAN":
        CAN=pd.read_csv(file,index_col=0)
    elif x=="ESP":
        ESP=pd.read_csv(file,index_col=0)
    elif x=="EUR":
        EUR=pd.read_csv(file,index_col=0)
    elif x=="FRA":
        FRA=pd.read_csv(file,index_col=0)
    elif x=="GBP":
        GBP=pd.read_csv(file,index_col=0)
    elif x=="GER":
        GER=pd.read_csv(file,index_col=0)
    elif x=="ITA":
        ITA=pd.read_csv(file,index_col=0)
    elif x=="JPN":
        JPN=pd.read_csv(file,index_col=0)
    elif x=="KOR":
        KOR=pd.read_csv(file,index_col=0)
    elif x=="MEX":
        MEX=pd.read_csv(file,index_col=0)
    elif x=="SUI":
        SUI=pd.read_csv(file,index_col=0)

# %%
len(countries)
# Out:
# 13

# %%
SUI.describe()
# Out:
#        acousticness  danceability    duration_ms     energy  instrumentalness  \
# count     87.000000     87.000000      87.000000  87.000000         87.000000
# mean       0.294056      0.689046  203556.563218   0.584920          0.014062
# std        0.266619      0.118082   29032.191113   0.154802          0.099083
# min        0.000055      0.380000  150896.000000   0.120000          0.000000
# 25%        0.037000      0.572000  189198.000000   0.481000          0.000000
# 50%        0.234000      0.705000  209438.000000   0.588000          0.000010
# 75%        0.462500      0.811000  213586.500000   0.730000          0.000104
# max        0.917000      0.837000  328000.000000   0.895000          0.860000
#
#              key   liveness   loudness       mode  speechiness       tempo  \
# count  87.000000  87.000000  87.000000  87.000000    87.000000   87.000000
# mean    5.655172   0.167392  -6.411333   0.448276     0.060889  114.028345
# ...

# %%
complete_dataframe=(
    ARG.merge(AUS, on="Date", suffixes=("_ARG", "_AUS"),how="outer")
    .merge(CAN, on="Date", how="outer")
    .merge(ESP, on="Date", suffixes=("_CAN", "_ESP"),how="outer")
    .merge(EUR, on="Date",how="outer")
    .merge(FRA, on="Date", suffixes=("_EUR", "_FRA"),how="outer")
    .merge(GER, on="Date",how="outer")
    .merge(GBP, on="Date", suffixes=("_GER","_GBP"),how="outer")
    .merge(ITA, on="Date",how="outer")
    .merge(JPN, on="Date", suffixes=("_ITA", "_JPN"),how="outer")
    .merge(KOR, on="Date", how="outer")
    .merge(MEX, on="Date", suffixes=("_KOR", "_MEX"),how="outer")
    .merge(SUI, on="Date", how="outer")
)

complete_dataframe
# Out:
#           Date                                         Artist_ARG  \
# 0   2019-01-05                                       Paulo Londra
# 1   2019-01-12                               Pedro Capo X Farruko
# 2   2019-01-19                               Pedro Capo X Farruko
# 3   2019-01-26                               Pedro Capo X Farruko
# 4   2019-02-02                               Pedro Capo X Farruko
# ..         ...                                                ...
# 82  2020-08-01  Trueno & Nicki Nicole Featuring Taiu, Bizarrap...
# 83  2020-08-08  Trueno & Nicki Nicole Featuring Taiu, Bizarrap...
# 84  2020-08-15  Trueno & Nicki Nicole Featuring Taiu, Bizarrap...
# 85  2020-08-22  Trueno & Nicki Nicole Featuring Taiu, Bizarrap...
# 86  2020-08-29                                             Maluma
#
#    TrackName_ARG                 uri_ARG  acousticness_ARG  danceability_ARG  \
# 0     Adan y Eva  6FyRXC8tJUh863JCkyWqtk             0.323             0.767
# ...

# %%
column_names=complete_dataframe.columns

[x for x in column_names]
# Out:
# ['Date',
#  'Artist_ARG',
#  'TrackName_ARG',
#  'uri_ARG',
#  'acousticness_ARG',
#  'danceability_ARG',
#  'duration_ms_ARG',
#  'energy_ARG',
#  'instrumentalness_ARG',
#  'key_ARG',
#  'liveness_ARG',
#  'loudness_ARG',
#  'mode_ARG',
#  'speechiness_ARG',
#  'tempo_ARG',
#  'time_signature_ARG',
#  'valence_ARG',
#  'Artist_AUS',
#  'TrackName_AUS',
#  'uri_AUS',
#  'acousticness_AUS',
#  'danceability_AUS',
#  'duration_ms_AUS',
#  'energy_AUS',
#  'instrumentalness_AUS',
#  'key_AUS',
#  'liveness_AUS',
#  'loudness_AUS',
#  'mode_AUS',
#  'speechiness_AUS',
#  'tempo_AUS',
#  'time_signature_AUS',
#  'valence_AUS',
#  'Artist_CAN',
#  'TrackName_CAN',
#  'aSearch_CAN',
#  'searcher_CAN',
#  'uri_CAN',
#  'acousticness_CAN',
#  'danceability_CAN',
#  'duration_ms_CAN',
#  'energy_CAN',
#  'instrumentalness_CAN',
#  'key_CAN',
#  'liveness_CAN',
#  'loudness_CAN',
#  'mode_CAN',
#  'speechiness_CAN',
#  'tempo_CAN',
#  'time_signature_CAN',
#  'valence_CAN',
#  'Artist_ESP',
# ...

# %%
import matplotlib.pyplot as plt

def create_column_names(variable_to_study):  

    for x in range(len(countries)):
        column_names.append(f'{variable_to_study}_{countries[x]}')

    column_names.remove(column_names[12])
    column_names.append(f'{variable_to_study}')

    return column_names

def create_boxplots():
    fig, axs = plt.subplots(1, len(column_names), figsize=(60, 40), sharey=True)

    for x in range(columns_for_analysis):  
        print(column_names[x])
        axs[x].boxplot(df_to_study[f'{column_names[x]}'])
        axs[x].set_title(f'{column_names[x]}')

    axs[0].set(ylabel=f'{variable_to_study}')
    fig.tight_layout()
    return

# %%
import matplotlib.pyplot as plt

column_names=[]
variable_to_study="valence"
total_valence={}
df_to_study=total_valence

column_names=create_column_names(variable_to_study)
columns_for_analysis=len(column_names)

df_to_study=complete_dataframe[column_names]

create_boxplots()

print(df_to_study)
df_to_study.describe()
# Out:
# valence_ARG
# valence_AUS
# valence_CAN
# valence_ESP
# valence_EUR
# valence_FRA
# valence_GBP
# valence_GER
# valence_ITA
# valence_JPN
# valence_KOR
# valence_MEX
# valence
#     valence_ARG  valence_AUS  valence_CAN  valence_ESP  valence_EUR  \
# 0         0.720        0.754        0.744        0.763        0.628
# 1         0.761        0.754        0.412        0.167        0.628
# 2         0.761        0.323        0.913        0.167        0.628
# 3         0.761        0.628        0.913        0.577        0.628
# 4         0.761        0.327        0.327        0.958        0.327
# ..          ...          ...          ...          ...          ...
# 82        0.346        0.115        0.450        0.497        0.761
# 83        0.346        0.761        0.894        0.182        0.761
# 84        0.346        0.761        0.761        0.497        0.761
# 85        0.346        0.761        0.357        0.497        0.761
# ...

# %%
[x for x in countries]
# Out:
# ['ARG',
#  'AUS',
#  'CAN',
#  'ESP',
#  'EUR',
#  'FRA',
#  'GBP',
#  'GER',
#  'ITA',
#  'JPN',
#  'KOR',
#  'MEX',
#  'SUI']

# %%
SUI
# Out:
#           Date                                          Artist  \
# 0   2019-01-05                      Lady Gaga & Bradley Cooper
# 1   2019-01-12                      Lady Gaga & Bradley Cooper
# 2   2019-01-19                      Lady Gaga & Bradley Cooper
# 3   2019-01-26                      Lady Gaga & Bradley Cooper
# 4   2019-02-02                                         Ava Max
# ..         ...                                             ...
# 82  2020-08-01                        Jawsh 685 x Jason Derulo
# 83  2020-08-08                        Jawsh 685 x Jason Derulo
# 84  2020-08-15                        Jawsh 685 x Jason Derulo
# 85  2020-08-22  Master KG Featuring Burna Boy & Nomcebo Zikode
# 86  2020-08-29  Master KG Featuring Burna Boy & Nomcebo Zikode
#
#                            TrackName                     uri  acousticness  \
# 0                            Shallow  2VxeLyX666F8uXCJ0dZF8B        0.3710
# ...
