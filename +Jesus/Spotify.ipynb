# %%
import pandas as pd

countries=["ARG","MEX","AUS", "CAN", "ESP", "FRA", "GBP", "GER", "ITA","SUI","EUR", "JPN", "KOR"]
files_name=[]
country_data={}

for x in countries:
    file=f'../Datasets/Billboard International Charts (2019-Aug 2020)/{x}.csv'
    if x=="ARG":        
        ARG=pd.read_csv(file,index_col=0)
    elif x=="AUS":
        AUS=pd.read_csv(file,index_col=0)
    elif x=="CAN":
        CAN=pd.read_csv(file,index_col=0)
    elif x=="ESP":
        ESP=pd.read_csv(file,index_col=0)
    elif x=="EUR":
        EUR=pd.read_csv(file,index_col=0)
    elif x=="FRA":
        FRA=pd.read_csv(file,index_col=0)
    elif x=="GBP":
        GBP=pd.read_csv(file,index_col=0)
    elif x=="GER":
        GER=pd.read_csv(file,index_col=0)
    elif x=="ITA":
        ITA=pd.read_csv(file,index_col=0)
    elif x=="JPN":
        JPN=pd.read_csv(file,index_col=0)
    elif x=="KOR":
        KOR=pd.read_csv(file,index_col=0)
    elif x=="MEX":
        MEX=pd.read_csv(file,index_col=0)
    elif x=="SUI":
        SUI=pd.read_csv(file,index_col=0)

# %%
len(countries)
# Out:
# 13

# %%
complete_dataframe=(
    ARG.merge(AUS, on="Date", suffixes=("_ARG", "_AUS"),how="inner")
    .merge(CAN, on="Date", how="inner")
    .merge(ESP, on="Date", suffixes=("_CAN", "_ESP"),how="inner")
    .merge(EUR, on="Date",how="inner")
    .merge(FRA, on="Date", suffixes=("_EUR", "_FRA"),how="inner")
    .merge(GER, on="Date",how="inner")
    .merge(GBP, on="Date", suffixes=("_GER","_GBP"),how="inner")
    .merge(ITA, on="Date",how="inner")
    .merge(JPN, on="Date", suffixes=("_ITA", "_JPN"),how="inner")
    .merge(KOR, on="Date", how="inner")
    .merge(MEX, on="Date", suffixes=("_KOR", "_MEX"),how="inner")
    .merge(SUI, on="Date", how="inner")
)

complete_dataframe=complete_dataframe.rename(columns={
"Artist":"Artist_SUI",
"TrackName":"TrackName_SUI",
"uri":"uri_SUI",
"acousticness":"acousticness_SUI",
"danceability":"danceability_SUI",
"duration_ms":"duration_ms_SUI",
"energy":"energy_SUI",
"instrumentalness":"instrumentalness_SUI",
"key":"key_SUI",
"liveness":"liveness_SUI",
"loudness":"loudness_SUI",
"mode":"mode_SUI",
"speechiness":"speechiness_SUI",
"tempo":"tempo_SUI",
"time_signature":"time_signature_SUI",
"valence":"valence_SUI"})

complete_dataframe.head()
# Out:
#          Date            Artist_ARG TrackName_ARG                 uri_ARG  \
# 0  2019-01-05          Paulo Londra    Adan y Eva  6FyRXC8tJUh863JCkyWqtk
# 1  2019-01-12  Pedro Capo X Farruko         Calma  5iwz1NiezX7WWjnCgY5TH4
# 2  2019-01-19  Pedro Capo X Farruko         Calma  5iwz1NiezX7WWjnCgY5TH4
# 3  2019-01-26  Pedro Capo X Farruko         Calma  5iwz1NiezX7WWjnCgY5TH4
# 4  2019-02-02  Pedro Capo X Farruko         Calma  5iwz1NiezX7WWjnCgY5TH4
#
#    acousticness_ARG  danceability_ARG  duration_ms_ARG  energy_ARG  \
# 0             0.323             0.767         258639.0       0.709
# 1             0.323             0.826         238200.0       0.773
# 2             0.323             0.826         238200.0       0.773
# 3             0.323             0.826         238200.0       0.773
# 4             0.323             0.826         238200.0       0.773
#
#    instrumentalness_ARG  key_ARG  ...  energy_SUI  instrumentalness_SUI  \
# 0                   0.0      1.0  ...       0.385                   0.0
# 1                   0.0     11.0  ...       0.385                   0.0
# 2                   0.0     11.0  ...       0.385                   0.0
# 3                   0.0     11.0  ...       0.385                   0.0
# 4                   0.0     11.0  ...       0.704                   0.0
#
#    key_SUI  liveness_SUI  loudness_SUI  mode_SUI  speechiness_SUI tempo_SUI  \
# 0      7.0         0.231        -6.362       1.0           0.0308    95.799
# 1      7.0         0.231        -6.362       1.0           0.0308    95.799
# 2      7.0         0.231        -6.362       1.0           0.0308    95.799
# 3      7.0         0.231        -6.362       1.0           0.0308    95.799
# 4      1.0         0.166        -4.724       1.0           0.0476   133.002
#
#   time_signature_SUI valence_SUI
# 0                4.0       0.323
# 1                4.0       0.323
# 2                4.0       0.323
# 3                4.0       0.323
# 4                4.0       0.628
#
# [5 rows x 230 columns]

# %%
column_names=complete_dataframe.columns

[x for x in column_names]
# Out:
# ['Date',
#  'Artist_ARG',
#  'TrackName_ARG',
#  'uri_ARG',
#  'acousticness_ARG',
#  'danceability_ARG',
#  'duration_ms_ARG',
#  'energy_ARG',
#  'instrumentalness_ARG',
#  'key_ARG',
#  'liveness_ARG',
#  'loudness_ARG',
#  'mode_ARG',
#  'speechiness_ARG',
#  'tempo_ARG',
#  'time_signature_ARG',
#  'valence_ARG',
#  'Artist_AUS',
#  'TrackName_AUS',
#  'uri_AUS',
#  'acousticness_AUS',
#  'danceability_AUS',
#  'duration_ms_AUS',
#  'energy_AUS',
#  'instrumentalness_AUS',
#  'key_AUS',
#  'liveness_AUS',
#  'loudness_AUS',
#  'mode_AUS',
#  'speechiness_AUS',
#  'tempo_AUS',
#  'time_signature_AUS',
#  'valence_AUS',
#  'Artist_CAN',
#  'TrackName_CAN',
#  'aSearch_CAN',
#  'searcher_CAN',
#  'uri_CAN',
#  'acousticness_CAN',
#  'danceability_CAN',
#  'duration_ms_CAN',
#  'energy_CAN',
#  'instrumentalness_CAN',
#  'key_CAN',
#  'liveness_CAN',
#  'loudness_CAN',
#  'mode_CAN',
#  'speechiness_CAN',
#  'tempo_CAN',
#  'time_signature_CAN',
#  'valence_CAN',
#  'Artist_ESP',
#  'TrackName_ESP',
#  'aSearch_ESP',
#  'searcher_ESP',
#  'uri_ESP',
#  'acousticness_ESP',
#  'danceability_ESP',
#  'duration_ms_ESP',
#  'energy_ESP',
#  'instrumentalness_ESP',
#  'key_ESP',
#  'liveness_ESP',
#  'loudness_ESP',
#  'mode_ESP',
#  'speechiness_ESP',
#  'tempo_ESP',
#  'time_signature_ESP',
#  'valence_ESP',
#  'Artist_EUR',
#  'TrackName_EUR',
#  'aSearch_EUR',
#  'searcher_EUR',
#  'uri_EUR',
#  'acousticness_EUR',
#  'danceability_EUR',
#  'duration_ms_EUR',
#  'energy_EUR',
#  'instrumentalness_EUR',
#  'key_EUR',
#  'liveness_EUR',
#  'loudness_EUR',
#  'mode_EUR',
#  'speechiness_EUR',
#  'tempo_EUR',
#  'time_signature_EUR',
#  'valence_EUR',
#  'Artist_FRA',
#  'TrackName_FRA',
#  'aSearch_FRA',
#  'searcher_FRA',
#  'uri_FRA',
#  'acousticness_FRA',
#  'danceability_FRA',
#  'duration_ms_FRA',
#  'energy_FRA',
#  'instrumentalness_FRA',
#  'key_FRA',
#  'liveness_FRA',
#  'loudness_FRA',
#  'mode_FRA',
#  'speechiness_FRA',
#  'tempo_FRA',
#  'time_signature_FRA',
#  'valence_FRA',
#  'Artist_GER',
#  'TrackName_GER',
#  'aSearch_GER',
#  'searcher_GER',
#  'uri_GER',
#  'acousticness_GER',
#  'danceability_GER',
#  'duration_ms_GER',
#  'energy_GER',
#  'instrumentalness_GER',
#  'key_GER',
#  'liveness_GER',
#  'loudness_GER',
#  'mode_GER',
#  'speechiness_GER',
#  'tempo_GER',
#  'time_signature_GER',
#  'valence_GER',
#  'Artist_GBP',
#  'TrackName_GBP',
#  'aSearch_GBP',
#  'searcher_GBP',
#  'uri_GBP',
#  'acousticness_GBP',
#  'danceability_GBP',
#  'duration_ms_GBP',
#  'energy_GBP',
#  'instrumentalness_GBP',
#  'key_GBP',
#  'liveness_GBP',
#  'loudness_GBP',
#  'mode_GBP',
#  'speechiness_GBP',
#  'tempo_GBP',
#  'time_signature_GBP',
#  'valence_GBP',
#  'Unnamed: 0.1',
#  'Artist_ITA',
#  'TrackName_ITA',
#  'aSearch_ITA',
#  'searcher_ITA',
#  'uri_ITA',
#  'acousticness_ITA',
#  'danceability_ITA',
#  'duration_ms_ITA',
#  'energy_ITA',
#  'instrumentalness_ITA',
#  'key_ITA',
#  'liveness_ITA',
#  'loudness_ITA',
#  'mode_ITA',
#  'speechiness_ITA',
#  'tempo_ITA',
#  'time_signature_ITA',
#  'valence_ITA',
#  'Artist_JPN',
#  'TrackName_JPN',
#  'aSearch_JPN',
#  'searcher_JPN',
#  'uri_JPN',
#  'acousticness_JPN',
#  'danceability_JPN',
#  'duration_ms_JPN',
#  'energy_JPN',
#  'instrumentalness_JPN',
#  'key_JPN',
#  'liveness_JPN',
#  'loudness_JPN',
#  'mode_JPN',
#  'speechiness_JPN',
#  'tempo_JPN',
#  'time_signature_JPN',
#  'valence_JPN',
#  'Artist_KOR',
#  'TrackName_KOR',
#  'aSearch_KOR',
#  'searcher_KOR',
#  'uri_KOR',
#  'acousticness_KOR',
#  'danceability_KOR',
#  'duration_ms_KOR',
#  'energy_KOR',
#  'instrumentalness_KOR',
#  'key_KOR',
#  'liveness_KOR',
#  'loudness_KOR',
#  'mode_KOR',
#  'speechiness_KOR',
#  'tempo_KOR',
#  'time_signature_KOR',
#  'valence_KOR',
#  'Artist_MEX',
#  'TrackName_MEX',
#  'aSearch_MEX',
#  'searcher_MEX',
#  'uri_MEX',
#  'acousticness_MEX',
#  'danceability_MEX',
#  'duration_ms_MEX',
#  'energy_MEX',
#  'instrumentalness_MEX',
#  'key_MEX',
#  'liveness_MEX',
#  'loudness_MEX',
#  'mode_MEX',
#  'speechiness_MEX',
#  'tempo_MEX',
#  'time_signature_MEX',
#  'valence_MEX',
#  'Artist_SUI',
#  'TrackName_SUI',
#  'uri_SUI',
#  'acousticness_SUI',
#  'danceability_SUI',
#  'duration_ms_SUI',
#  'energy_SUI',
#  'instrumentalness_SUI',
#  'key_SUI',
#  'liveness_SUI',
#  'loudness_SUI',
#  'mode_SUI',
#  'speechiness_SUI',
#  'tempo_SUI',
#  'time_signature_SUI',
#  'valence_SUI']

# %%
import matplotlib.pyplot as plt
import numpy as np

def create_column_names(variable_to_study):  
    study_column_names=[]
    for x in range(len(countries)):
        study_column_names.append(f'{variable_to_study}_{countries[x]}')

    return study_column_names

def create_boxplots():
    df_to_study.plot(kind="box",rot=0, figsize=(10,5),colormap='Dark2',title=variable_to_study)
    plt.xticks(np.arange(1,14),countries)
    return plt.show()

# %%
variable_to_study="valence"

study_column_names=create_column_names(variable_to_study)
columns_for_analysis=len(study_column_names)

df_to_study=complete_dataframe[study_column_names]

create_boxplots()

# print(df_to_study)
df_to_study.describe()
# Out:
#        valence_ARG  valence_MEX  valence_AUS  valence_CAN  valence_ESP  \
# count    84.000000    84.000000    84.000000    84.000000    84.000000
# mean      0.672440     0.705774     0.524036     0.582896     0.563988
# std       0.112925     0.187078     0.182483     0.194347     0.219584
# min       0.346000     0.334000     0.115000     0.060500     0.167000
# 25%       0.574000     0.547500     0.334000     0.446000     0.327000
# 50%       0.704000     0.729000     0.513000     0.639000     0.513000
# 75%       0.761000     0.844750     0.639000     0.643000     0.820000
# max       0.940000     0.963000     0.952000     0.952000     0.958000
#
#        valence_FRA  valence_GBP  valence_GER  valence_ITA  valence_SUI  \
# count    84.000000    84.000000    84.000000    84.000000    84.000000
# mean      0.465560     0.563449     0.519179     0.566214     0.523398
# std       0.198171     0.197287     0.168861     0.197877     0.210036
# min       0.119000     0.051700     0.212000     0.141000     0.037700
# 25%       0.331250     0.441500     0.334000     0.439750     0.334000
# 50%       0.381000     0.513000     0.513000     0.591000     0.513000
# 75%       0.543250     0.750000     0.640000     0.752750     0.750000
# max       0.961000     0.905000     0.851000     0.867000     0.930000
#
#        valence_EUR  valence_JPN  valence_KOR
# count    84.000000    83.000000    84.000000
# mean      0.551699     0.492517     0.562583
# std       0.185152     0.206796     0.222921
# min       0.051700     0.000010     0.168000
# 25%       0.360250     0.369000     0.351000
# 50%       0.513000     0.446000     0.589000
# 75%       0.750000     0.659000     0.755000
# max       0.842000     0.967000     0.915000

# %%
variable_to_study="energy"

study_column_names=create_column_names(variable_to_study)
columns_for_analysis=len(study_column_names)

df_to_study=complete_dataframe[study_column_names]

create_boxplots()

# print(df_to_study)
df_to_study.describe()
# Out:
#        energy_ARG  energy_MEX  energy_AUS  energy_CAN  energy_ESP  energy_FRA  \
# count   84.000000   84.000000   84.000000   84.000000   84.000000   84.000000
# mean     0.772679    0.702524    0.594998    0.575179    0.662988    0.558405
# std      0.068176    0.133204    0.130311    0.123231    0.145765    0.144103
# min      0.637000    0.390000    0.054800    0.317000    0.145000    0.210000
# 25%      0.715000    0.602250    0.579500    0.540000    0.564000    0.442000
# 50%      0.773000    0.712000    0.588000    0.588000    0.632000    0.588000
# 75%      0.808000    0.821000    0.708250    0.619000    0.745000    0.698000
# max      0.901000    0.888000    0.855000    0.855000    0.917000    0.855000
#
#        energy_GBP  energy_GER  energy_ITA  energy_SUI  energy_EUR  energy_JPN  \
# count   84.000000   84.000000   84.000000   84.000000   84.000000   83.000000
# mean     0.623452    0.658012    0.649714    0.590536    0.627762    0.711497
# std      0.137970    0.104962    0.120918    0.154503    0.143825    0.208810
# min      0.219000    0.414000    0.385000    0.120000    0.219000    0.000229
# 25%      0.540000    0.588000    0.588000    0.496750    0.540000    0.621500
# 50%      0.664000    0.668000    0.665500    0.588000    0.588000    0.720000
# 75%      0.730000    0.730000    0.730000    0.730000    0.730000    0.869000
# max      0.874000    0.921000    0.916000    0.895000    0.895000    0.994000
#
#        energy_KOR
# count   84.000000
# mean     0.710940
# std      0.181531
# min      0.248000
# 25%      0.600000
# 50%      0.782000
# 75%      0.862000
# max      0.959000

# %%
variable_to_study="loudness"

study_column_names=create_column_names(variable_to_study)
columns_for_analysis=len(study_column_names)

df_to_study=complete_dataframe[study_column_names]

create_boxplots()

# print(df_to_study)
df_to_study.describe()
# Out:
#        loudness_ARG  loudness_MEX  loudness_AUS  loudness_CAN  loudness_ESP  \
# count     84.000000     84.000000     84.000000      84.00000      84.00000
# mean      -3.359393     -5.073619     -6.307000      -6.53694      -5.40569
# std        0.853880      1.282531      1.771092       1.60447       2.97562
# min       -5.893000     -8.520000    -16.008000     -10.96500     -18.25400
# 25%       -4.027000     -6.017000     -6.400000      -6.68700      -6.63600
# 50%       -3.280000     -5.041000     -6.119000      -5.93400      -4.07200
# 75%       -2.652000     -4.298250     -5.560000      -5.56000      -3.58725
# max       -2.331000     -2.592000     -3.764000      -3.76400      -2.16600
#
#        loudness_FRA  loudness_GBP  loudness_GER  loudness_ITA  loudness_SUI  \
# count     84.000000     84.000000     84.000000     84.000000     84.000000
# mean      -7.165238     -6.244833     -6.254821     -5.868631     -6.397452
# std        2.239683      1.845592      1.504228      1.141362      1.286678
# min      -19.576000    -13.273000    -11.712000     -8.285000    -13.273000
# 25%       -7.603750     -6.400000     -6.792000     -6.400000     -6.400000
# 50%       -6.381000     -5.934000     -6.039000     -5.934000     -6.362000
# 75%       -5.934000     -5.219250     -5.242000     -5.080000     -5.934000
# max       -3.764000     -3.158000     -3.161000     -3.207000     -3.578000
#
#        loudness_EUR  loudness_JPN  loudness_KOR
# count     84.000000     83.000000     84.000000
# mean      -6.139786     -6.532518     -4.247310
# std        1.595480      4.586819      1.792673
# min      -13.273000    -28.179000     -8.675000
# 25%       -6.400000     -8.697500     -5.095750
# 50%       -5.934000     -5.235000     -4.110500
# 75%       -5.097000     -3.464000     -3.063500
# max       -3.764000     -1.106000     -1.339000

# %%
variable_to_study="danceability"

study_column_names=create_column_names(variable_to_study)
columns_for_analysis=len(study_column_names)

df_to_study=complete_dataframe[study_column_names]

create_boxplots()

# print(df_to_study)
df_to_study.describe()
# Out:
#        danceability_ARG  danceability_MEX  danceability_AUS  danceability_CAN  \
# count         84.000000          84.00000         84.000000         84.000000
# mean           0.768964           0.73969          0.717274          0.766571
# std            0.057930           0.09358          0.141229          0.128350
# min            0.659000           0.50500          0.359000          0.488000
# 25%            0.725000           0.67500          0.572000          0.738750
# 50%            0.803000           0.76000          0.767000          0.785000
# 75%            0.803000           0.80450          0.824000          0.878000
# max            0.882000           0.88200          0.878000          0.896000
#
#        danceability_ESP  danceability_FRA  danceability_GBP  danceability_GER  \
# count         84.000000         84.000000         84.000000         84.000000
# mean           0.574036          0.661452          0.717607          0.721583
# std            0.185073          0.142289          0.135833          0.128033
# min            0.169000          0.249000          0.265000          0.480000
# 25%            0.400000          0.514000          0.679500          0.631000
# 50%            0.572000          0.702000          0.759000          0.759000
# 75%            0.791000          0.804500          0.817000          0.824000
# max            0.836000          0.878000          0.885000          0.941000
#
#        danceability_ITA  danceability_SUI  danceability_EUR  danceability_JPN  \
# count         84.000000         84.000000         84.000000         83.000000
# mean           0.705417          0.686917          0.694155          0.561783
# std            0.139465          0.117262          0.136778          0.133196
# min            0.357000          0.380000          0.265000          0.108000
# 25%            0.571000          0.572000          0.514000          0.520500
# 50%            0.763000          0.705000          0.759000          0.540000
# 75%            0.824000          0.795000          0.807000          0.637500
# max            0.874000          0.824000          0.824000          0.882000
#
#        danceability_KOR
# count         84.000000
# mean           0.650131
# std            0.124068
# min            0.403000
# 25%            0.563000
# 50%            0.645000
# 75%            0.728000
# max            0.874000
